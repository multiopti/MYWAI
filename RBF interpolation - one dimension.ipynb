# %% [markdown]
# # RBF interpolation examples - one dimension

# %%
import numpy as np
import matplotlib.pyplot as plt
from RBFN import RBFN
from numpy import linalg as LA

# %% [markdown]
# # y = x

# %%
# generating data
x = np.linspace(-1, 1, 100)
y = x

# fitting RBF-Network with data
model = RBFN(hidden_shape=10, sigma=1)
model.fit(x, y)
y_pred = model.predict(x)
print('Error quadratic norm = ',LA.norm(y - y_pred))

# plotting 1D interpolation
plt.plot(x, y, 'b-', label='real')
plt.plot(x, y_pred, 'r-', label='fit')
plt.legend(loc='upper right')
plt.title('Interpolation using a RBFN')
plt.show()
# Out:
# Error quadratic norm =  0.001262956022918529

# %% [markdown]
# # y = x^2

# %%
# generating data
x = np.linspace(-1, 1, 100)
y = np.square(x)

# fitting RBF-Network with data
model = RBFN(hidden_shape=10, sigma=1)
model.fit(x, y)
y_pred = model.predict(x)
print('Error quadratic norm = ',LA.norm(y - y_pred))

# plotting 1D interpolation
plt.plot(x, y, 'b-', label='real')
plt.plot(x, y_pred, 'r-', label='fit')
plt.legend(loc='upper right')
plt.title('Interpolation using a RBFN')
plt.show()
# Out:
# Error quadratic norm =  0.0006558486472306714

# %% [markdown]
# # y = x^3

# %%
# generating data
x = np.linspace(-1, 1, 100)
y = x**3


# fitting RBF-Network with data
model = RBFN(hidden_shape=10, sigma=1)
model.fit(x, y)
y_pred = model.predict(x)
print('Error quadratic norm = ',LA.norm(y - y_pred))

# plotting 1D interpolation
plt.plot(x, y, 'b-', label='real')
plt.plot(x, y_pred, 'r-', label='fit')
plt.legend(loc='upper right')
plt.title('Interpolation using a RBFN')
plt.show()
# Out:
# Error quadratic norm =  0.003716756894562403

# %% [markdown]
# # y = x^4

# %%
# generating data
x = np.linspace(-1, 1, 100)
y = x**4
#y = np.sqrt(x)
#y = np.sin(100*x)
#y = np.sign(x)

# fitting RBF-Network with data
model = RBFN(hidden_shape=10, sigma=1)
model.fit(x, y)
y_pred = model.predict(x)
print('Error quadratic norm = ',LA.norm(y - y_pred))

# plotting 1D interpolation
plt.plot(x, y, 'b-', label='real')
plt.plot(x, y_pred, 'r-', label='fit')
plt.legend(loc='upper right')
plt.title('Interpolation using a RBFN')
plt.show()
# Out:
# Error quadratic norm =  0.0021672692417990303

# %% [markdown]
# # y = e^(-x)

# %%
# generating data
x = np.linspace(-1, 1, 100)
y = np.exp(-x)


# fitting RBF-Network with data
model = RBFN(hidden_shape=10, sigma=1)
model.fit(x, y)
y_pred = model.predict(x)
print('Error quadratic norm = ',LA.norm(y - y_pred))

# plotting 1D interpolation
plt.plot(x, y, 'b-', label='real')
plt.plot(x, y_pred, 'r-', label='fit')
plt.legend(loc='upper right')
plt.title('Interpolation using a RBFN')
plt.show()
# Out:
# Error quadratic norm =  0.0005686102248278037

# %% [markdown]
# # y = sin(2*pi*x)

# %%
# generating data
x = np.linspace(-1, 1, 100)
y = np.sin(2*np.pi*x)

# fitting RBF-Network with data
model = RBFN(hidden_shape=10, sigma=1)
model.fit(x, y)
y_pred = model.predict(x)
print('Error quadratic norm = ',LA.norm(y - y_pred))

# plotting 1D interpolation
plt.plot(x, y, 'b-', label='real')
plt.plot(x, y_pred, 'r-', label='fit')
plt.legend(loc='upper right')
plt.title('Interpolation using a RBFN')
plt.show()
# Out:
# Error quadratic norm =  0.0021428088837200094

# %% [markdown]
# # In some cases, it does not work like for y = sign(x), which is discontinuous at x = 0

# %%
# generating data
x = np.linspace(-1, 1, 100)
y = np.sign(x)

# fitting RBF-Network with data
model = RBFN(hidden_shape=10, sigma=1)
model.fit(x, y)
y_pred = model.predict(x)
print('Error quadratic norm = ',LA.norm(y - y_pred))

# plotting 1D interpolation
plt.plot(x, y, 'b-', label='real')
plt.plot(x, y_pred, 'r-', label='fit')
plt.legend(loc='upper right')
plt.title('Interpolation using a RBFN')
plt.show()
# Out:
# Error quadratic norm =  2.5983730033858343

# %% [markdown]
# # Or sine waves with higher frequency

# %%
# generating data
x = np.linspace(-1, 1, 100)
y = np.sin(10*np.pi*x)

# fitting RBF-Network with data
model = RBFN(hidden_shape=10, sigma=1)
model.fit(x, y)
y_pred = model.predict(x)
print('Error quadratic norm = ',LA.norm(y - y_pred))

# plotting 1D interpolation
plt.plot(x, y, 'b-', label='real')
plt.plot(x, y_pred, 'r-', label='fit')
plt.legend(loc='upper right')
plt.title('Interpolation using a RBFN')
plt.show()
# Out:
# Error quadratic norm =  6.917467212660235
